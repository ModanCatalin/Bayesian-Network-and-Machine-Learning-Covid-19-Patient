# %% [markdown]
# # Machine Learning for predicting the survival of a person infected with the COVID-19 virus

# %% [markdown]
# In acest proiect am incercat sa implementez un model care sa poata prezice dacă o persoană infectata cu virusul COVID-19 va muri sau nu.

# %%
import sklearn
import graphviz
import pandas as pd
import numpy as np

np.random.seed(63)

# %%
DATA_FILE = 'Patient-Medical-Data-for-Novel-Coronavirus-COVID-19.csv'
dataFile = pd.read_csv(DATA_FILE, sep=',')
dataFile.describe()
# Out:
#                        Age                         Sex  \
# count               213684                      213684
# unique                 216                           3
# top     Interval[{35, 59}]  Entity["Gender", "Female"]
# freq                 66683                      111711
#
#                            City  \
# count                    213684
# unique                     1005
# top     Missing["NotAvailable"]
# freq                      82354
#
#                                    AdministrativeDivision  \
# count                                              213684
# unique                                                421
# top     Entity["AdministrativeDivision", {"Bavaria", "...
# freq                                                42594
#
#                              Country  \
# count                         213684
# unique                           135
# top     Entity["Country", "Germany"]
# freq                          160356
#
#                                               GeoPosition  \
# count                                              213684
# unique                                               2390
# top     GeoPosition[{48.13641000000007, 11.57754000000...
# freq                                                 6981
#
#             DateOfOnsetSymptoms  DateOfAdmissionHospital  \
# count                    213684                   213684
# unique                      134                       96
# top     Missing["NotAvailable"]  Missing["NotAvailable"]
# freq                      48913                   211620
#
#                                        DateOfConfirmation  \
# count                                              213684
# unique                                                124
# top     DateObject[{2020, 4, 2}, "Day", "Gregorian", -5.]
# freq                                                 8384
#
#                        Symptoms  ...    TravelHistoryLocation  \
# count                    213684  ...                   213684
# unique                      322  ...                      475
# top     Missing["NotAvailable"]  ...  Missing["NotAvailable"]
# freq                     211984  ...                   208168
#
#          ReportedMarketExposure ReportedMarketExposureComment ChronicDiseaseQ  \
# count                    213684                        213684          213684
# unique                        3                             8               2
# top     Missing["NotAvailable"]       Missing["NotAvailable"]           False
# freq                     213608                        213669          213028
#
#                 ChronicDiseases        SequenceAvailable  \
# count                    213684                   213684
# unique                       66                        2
# top     Missing["NotAvailable"]  Missing["NotAvailable"]
# freq                     213539                   213679
#
#                     DischargedQ                   DeathQ  \
# count                    213684                   213684
# unique                        2                        2
# top     Missing["NotAvailable"]  Missing["NotAvailable"]
# freq                     213567                   213532
#
#                     DateOfDeath          DateOfDischarge
# count                    213684                   213684
# unique                       40                       66
# top     Missing["NotAvailable"]  Missing["NotAvailable"]
# freq                     213536                   213340
#
# [4 rows x 23 columns]

# %% [markdown]
# Privind aceste date, pot vedea că am o multime de date care lipsesc. De asemenea, pot folosi cateva coloane pentru a deduce valoarea pentru DeathQ, campul pe care trebuie sa il prezic. DischargedQ inseamna ca pacientul a fost vindecat si externat din spital, daca acesta este cazul inseamna ca pacientul nu a murit, astfel incat sa putem pune valoarea fals in DeathQ.

# %% [markdown]
# Cu toate ca de obicei mai multe date inseamna precizie mai buna, anumite date din tabel sunt inutile referitor la rata de supravietuire a unui pacient.

# %%
dataFile.loc[dataFile.DateOfDeath != 'Missing["NotAvailable"]', 'DeathQ'] = 'True'
dataFile.loc[dataFile.DischargedQ == 'True', 'DeathQ'] = 'False'
dataFile.loc[dataFile.DateOfDischarge != 'Missing["NotAvailable"]', 'DeathQ'] = 'False'

dataFile = dataFile.drop(dataFile[dataFile.DeathQ == 'Missing["NotAvailable"]'].index)
dataFile = dataFile.drop(columns=['ReportedMarketExposureComment', 'DischargedQ', 'SequenceAvailable', 'GeoPosition', 'LivesInWuhan',
                      'ReportedMarketExposure', 'LivesInWuhanComment', 'DateOfOnsetSymptoms'])

# %%
dataFile.describe()
# Out:
#                             Age                       Sex  \
# count                       530                       530
# unique                       92                         3
# top     Missing["NotAvailable"]  Entity["Gender", "Male"]
# freq                         39                       308
#
#                            City   AdministrativeDivision  \
# count                       530                      530
# unique                       71                       70
# top     Missing["NotAvailable"]  Missing["NotAvailable"]
# freq                        241                      266
#
#                                  Country  DateOfAdmissionHospital  \
# count                                530                      530
# unique                                30                       63
# top     Entity["Country", "Philippines"]  Missing["NotAvailable"]
# freq                                 140                      280
#
#              DateOfConfirmation                 Symptoms  \
# count                       530                      530
# unique                       72                       96
# top     Missing["NotAvailable"]  Missing["NotAvailable"]
# freq                         43                      329
#
#              TravelHistoryDates    TravelHistoryLocation ChronicDiseaseQ  \
# count                       530                      530             530
# unique                       37                       37               2
# top     Missing["NotAvailable"]  Missing["NotAvailable"]           False
# freq                        414                      359             385
#
#                 ChronicDiseases DeathQ              DateOfDeath  \
# count                       530    530                      530
# unique                       55      2                       40
# top     Missing["NotAvailable"]  False  Missing["NotAvailable"]
# freq                        409    378                      382
#
#                 DateOfDischarge
# count                       530
# unique                       66
# top     Missing["NotAvailable"]
# freq                        186

# %%
dataFile.describe()
# Out:
#                             Age                       Sex  \
# count                       530                       530
# unique                       92                         3
# top     Missing["NotAvailable"]  Entity["Gender", "Male"]
# freq                         39                       308
#
#                            City   AdministrativeDivision  \
# count                       530                      530
# unique                       71                       70
# top     Missing["NotAvailable"]  Missing["NotAvailable"]
# freq                        241                      266
#
#                                  Country  DateOfAdmissionHospital  \
# count                                530                      530
# unique                                30                       63
# top     Entity["Country", "Philippines"]  Missing["NotAvailable"]
# freq                                 140                      280
#
#              DateOfConfirmation                 Symptoms  \
# count                       530                      530
# unique                       72                       96
# top     Missing["NotAvailable"]  Missing["NotAvailable"]
# freq                         43                      329
#
#              TravelHistoryDates    TravelHistoryLocation ChronicDiseaseQ  \
# count                       530                      530             530
# unique                       37                       37               2
# top     Missing["NotAvailable"]  Missing["NotAvailable"]           False
# freq                        414                      359             385
#
#                 ChronicDiseases DeathQ              DateOfDeath  \
# count                       530    530                      530
# unique                       55      2                       40
# top     Missing["NotAvailable"]  False  Missing["NotAvailable"]
# freq                        409    378                      382
#
#                 DateOfDischarge
# count                       530
# unique                       66
# top     Missing["NotAvailable"]
# freq                        186

# %%
from sklearn.impute import SimpleImputer

i = SimpleImputer(missing_values='Missing["NotAvailable"]', strategy='most_frequent')
i.fit(dataFile)
trans = i.transform(dataFile)
dataFile = pd.DataFrame(trans, columns=dataFile.columns)

# %% [markdown]
# Urmeaza sa ne uitam la datele noastre, referitor la simptome si la celelalte boli care pot avea un efect negativ asupra supravietuirii pacientului.

# %%
dataFile['ChronicDiseaseQ'].value_counts()
# Out:
# False    385
# True     145
# Name: ChronicDiseaseQ, dtype: int64

# %%
dataFile['ChronicDiseases'].value_counts()
# Out:
# {"hypertension"}                                                                                                   432
# {"hypertension", "diabetes"}                                                                                        13
# {"diabetes", "hypertension"}                                                                                        10
# {"diabetes"}                                                                                                         7
# {"chronic obstructive pulmonary disease"}                                                                            4
# {"asthma"}                                                                                                           3
# {"hypertension", "chronic kidney disease"}                                                                           3
# {"chronic kidney disease"}                                                                                           3
# {"hepatitis B", "diabetes"}                                                                                          2
# {"chronic bronchitis"}                                                                                               2
# {"prostate hypertrophy"}                                                                                             2
# {"hypertension", "cardiac disease"}                                                                                  2
# {"chronic kidney disease", "hypertension", "diabetes"}                                                               2
# {"hypertension", "type 2 diabetes", "coronary heart disease", "coronary stent", "lung cancer"}                       2
# {"hypertension", "diabetes", "dyslipidemia"}                                                                         2
# {"hypertension", "diabetes", "asthma"}                                                                               2
# {"hypertension", "diabetes", "chronic kidney disease"}                                                               2
# {"Parkinson's disease"}                                                                                              1
# {"benign prostatic hyperplasia"}                                                                                     1
# {"diabetes", "hypertension", "chronic kidney disease"}                                                               1
# {"atrial fibrillation", "hypertension", "atherosclerosis", "cerebrovascular infarct"}                                1
# {"hypertension", "kidney disease"}                                                                                   1
# {"hyperthyroidism"}                                                                                                  1
# {"prostate cancer", "chronic obstructive pulmonary disease"}                                                         1
# {"diabetes", "hypertension", "upper gastrointestinal bleeding"}                                                      1
# {"coronary heart disease"}                                                                                           1
# {"hypertension", "colon cancer"}                                                                                     1
# {"hypertension", "cerebral infarction", "encephalomalacia"}                                                          1
# {"hypertension", "hypothyroidism"}                                                                                   1
# {"prerenal azotemia", "cardiomyopathy", "hypertension", "diabetes"}                                                  1
# {"asthma", "hypertension", "atherosclerosis", "coronary heart disease"}                                              1
# {"hypertension", "diabetes", "coronary heart disease", "frequent ventricular premature beat", "coronary stent"}      1
# {"chronic bronchitis", "stenocardia", "hypertension", "coronary stent", "hemorrhage of digestive tract"}             1
# {"diabetes", "coronary heart disease"}                                                                               1
# {"hypertension", "diabetes", "tongue cancer", "cardiovascular disease", "benign prostatic hypertrophy"}              1
# {"hypertension", "coronary heart disease", "diabetes"}                                                               1
# {"hypertension", "diabetes", "colon cancer"}                                                                         1
# {"hypertension", "hypothyroidism", "kidney disease"}                                                                 1
# {"diabetes", "cerebral infarction"}                                                                                  1
# {"cardiac disease"}                                                                                                  1
# {"asthma", "diabetes"}                                                                                               1
# {"hypertension", "coronary heart disease", "diabetes", "tuberculosis"}                                               1
# {"hypertension", "hip replacement"}                                                                                  1
# {"chronic kidney disease", "hypertension"}                                                                           1
# {"prerenal azotemia", "diabetes", "hypertension"}                                                                    1
# {"chronic obstructive pulmonary disease", "diabetes", "dyslipidemia"}                                                1
# {"hypertension", "bronchial asthma", "impaired fasting glucose"}                                                     1
# {"hypertension", "chronic obstructive pulmonary disease", "diabetes", "chronic renal insufficiency"}                 1
# {"hypertension", "diabetes", "valvular heart disease"}                                                               1
# {"diabetes", "cardiac dysrhythmia"}                                                                                  1
# {"chronic kidney disease", "hypertension", "diabetes", "coronary heart disease"}                                     1
# {"hypertension", "diabetes", "Parkinson's disease"}                                                                  1
# {"hypertension", "diabetes", "cardiac disease"}                                                                      1
# {"hypertension", "cerebrovascular accident infarct"}                                                                 1
# Name: ChronicDiseases, dtype: int64

# %%
dataFile['Symptoms'].value_counts()
# Out:
# {"acute respiratory distress syndrome", "pneumonia"}    346
# {"fever"}                                                16
# {"cough", "fever"}                                       14
# {"acute respiratory failure", "pneumonia"}               11
# {"pneumonia"}                                             8
#                                                        ...
# {"cough", "sore throat", "headache"}                      1
# {"dizziness", "fever"}                                    1
# {"cough", "fatigue", "fever", "headache"}                 1
# {"shortness of breath"}                                   1
# {"cough", "fever", "chills"}                              1
# Name: Symptoms, Length: 95, dtype: int64

# %%
X, y = dataFile.loc[:, dataFile.columns != 'DeathQ'], dataFile['DeathQ']

from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder()
X = ohe.fit_transform(X)

# %%
dataFile.describe()
# Out:
#         Age                       Sex  \
# count   530                       530
# unique   91                         2
# top      56  Entity["Gender", "Male"]
# freq     53                       344
#
#                                                City  \
# count                                           530
# unique                                           70
# top     Entity["City", {"Wuhan", "Hubei", "China"}]
# freq                                            282
#
#                                    AdministrativeDivision  \
# count                                                 530
# unique                                                 69
# top     Entity["AdministrativeDivision", {"Hubei", "Ch...
# freq                                                  308
#
#                                  Country  \
# count                                530
# unique                                29
# top     Entity["Country", "Philippines"]
# freq                                 142
#
#                                   DateOfAdmissionHospital  \
# count                                                 530
# unique                                                 62
# top     DateObject[{2020, 1, 23}, "Day", "Gregorian", ...
# freq                                                  293
#
#                                        DateOfConfirmation  \
# count                                                 530
# unique                                                 71
# top     DateObject[{2020, 2, 3}, "Day", "Gregorian", -5.]
# freq                                                   65
#
#                                                  Symptoms  \
# count                                                 530
# unique                                                 95
# top     {"acute respiratory distress syndrome", "pneum...
# freq                                                  346
#
#                                        TravelHistoryDates  \
# count                                                 530
# unique                                                 36
# top     DateObject[{2020, 1, 17}, "Day", "Gregorian", ...
# freq                                                  424
#
#                                 TravelHistoryLocation ChronicDiseaseQ  \
# count                                             530             530
# unique                                             36               2
# top     {Entity["City", {"Wuhan", "Hubei", "China"}]}           False
# freq                                              457             385
#
#          ChronicDiseases DeathQ  \
# count                530    530
# unique                54      2
# top     {"hypertension"}  False
# freq                 432    378
#
#                                               DateOfDeath  \
# count                                                 530
# unique                                                 39
# top     DateObject[{2020, 1, 23}, "Day", "Gregorian", ...
# freq                                                  394
#
#                                           DateOfDischarge
# count                                                 530
# unique                                                 65
# top     DateObject[{2020, 2, 18}, "Day", "Gregorian", ...
# freq                                                  208

# %%
dataFile['DeathQ'].value_counts()
# Out:
# False    378
# True     152
# Name: DeathQ, dtype: int64

# %%
from sklearn.model_selection import StratifiedShuffleSplit

sss = StratifiedShuffleSplit(n_splits=1, test_size=0.1, random_state=63)
for train_index, test_index in sss.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

# %%
train = dataFile.iloc[train_index]
test = dataFile.iloc[test_index]

train.to_csv("train.csv")
test.to_csv("test.csv")

# %% [markdown]
# DeathQ -urile sunt disproporționate, așa că există șanse mari ca atunci când impart valorile în setul de invatare si setul de test,acestea să fie și mai disproporționate ca la inceput. Pentru a elimina aceasta posibilitate, am ales StratifiedShuffleSplit din sklearn, ceea ce asigură că aceeasi proporție de True și False poate fi gasita în ambele seturi.

# %% [markdown]
# # Arbore de decizie

# %% [markdown]
# Este evident ca unele variabile conteaza mai mult ca altele, ar fii aiurea sa spui ca conditiile preliminare ale unui pacient au acelasi impact asupra rata lui de supravietuire ca tara din care fac parte, de exemplu.

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(clf, X_test, y_test)
print("Accuracy: %f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.903636 (+/- 0.13)

# %% [markdown]
# Obtinem o acuratete de 0.90, ceea ce pare destul de bine, avand in vedere ca numarul de date real pe care il procesam, dupa ce le eliminam pe cele inutile.Urmeaza sa incercam sa vedem arborele de decizie si sa vedem ierarhia de importanta in luarea unei decizii.

# %%
import graphviz 
columns = list(dataFile.columns)
columns.remove('DeathQ')

feature_names = ohe.get_feature_names(columns)
dot_data = tree.export_graphviz(clf, out_file=None,
                               feature_names=feature_names,
                               class_names=np.unique(y),
                               filled=True, rounded=True,
                               special_characters=True) 
graph = graphviz.Source(dot_data)

# %% [markdown]
# # MLP

# %% [markdown]
# Urmeaza sa folosim un Multi Layer Perceptor pentru a procesa aceleasi date  si a trage anumite concluzii referitor la care metoda este mai buna. In continuare o sa ne referim la Multi Layer Perceptor prin abrevierea lui MLP.

# %% [markdown]
# Un MLP este unul din clasele "feedforward" ale unui ANN(artificial neural network), in care conexiunile dintre noduri nu formeaza nu ciclu ceea ce o sa vedem ca este convenabil pentru acest tip de analiza al datelor noastre. Pentru această metoda am folosit implementarea implicită de la sklearn cu (1000) ca hidden layer size.

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(max_iter=1000)

# %%
mlp.fit(X_train, y_train)
# Out:
# MLPClassifier(max_iter=1000)

# %%
scores = cross_val_score(mlp, X_test, y_test)
print("Accuracy: %f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.940000 (+/- 0.16)

# %% [markdown]
# # Observatii finale

# %% [markdown]
# Dupa cum putem observa, MLP ofera rezultate mai bune cu o deviatie standard mai mare pentru aceleasi date. Acuratetea este cu 4 procente mai mare, lucru care este foarte semnificativ avand in vedere volumul de date cu care lucram, desi nu putem sa fim niciodata prea siguri daca acelasi lucru s-ar observa si pe un volum mare de date, dar pentru cu cat lucram, MLP > DecisionTree.
